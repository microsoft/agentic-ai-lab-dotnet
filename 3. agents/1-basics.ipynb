# %% [markdown]
# # 🍏 Fun & Fit Health Advisor Agent Tutorial 🍎
#
# Welcome to our **Fun & Fit Health Advisor Agent** tutorial, where you'll use **Azure AI Foundry** SDKs to create a playful (yet carefully disclaimed!) health and fitness assistant. We'll:
#
# 1. **Initialize** our project using Azure.AI.Projects.
# 2. **Create** an Agent specialized in providing general wellness and nutritional advice (with disclaimers!).
# 3. **Manage** conversations about fitness, nutrition, and general health topics.
# 4. **Showcase** logging and tracing with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, safety disclaimers, and basic best practices.
#
# ## ⚠️ Important Medical Disclaimer ⚠️
# > **The health information provided by this notebook is for general educational and entertainment purposes only and is not intended as a substitute for professional medical advice, diagnosis, or treatment**. Always seek the advice of your physician or other qualified health provider with any questions you may have regarding a medical condition. Never disregard professional medical advice or delay seeking it because of something you read or receive from this notebook.
#
# ## Prerequisites
# Complete [the notebooks in introduction](../1.%20initial-setup/quick_start.ipynb)
#
#
# ## Let's Get Started
#
# We'll walk you through each cell with notes and diagrams to keep it fun. Let's begin!
#
# <img src="seq-diagrams/1-basics.png">

# %% [markdown]
# # 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# > az login --use-device-code
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
#
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# # 1. Initial Setup
#
# We'll start by importing needed libraries, loading environment variables, and initializing an AIProjectClient so we can do all the agent-related actions. Let's do it! 🎉

# %%
#pragma warning disable OPENAI001

#r "nuget: Azure.Identity, 1.18.0-beta.2"
#r "nuget: Azure.AI.Projects, 1.2.0-beta.5"
#r "nuget: dotenv.net"

using System.IO;
using System.ClientModel.Primitives;
using Azure.Identity;
using Azure.AI.Projects;
using Azure.AI.Projects.OpenAI;
using OpenAI.Responses;
using dotenv.net;  

DotEnv.Load(new DotEnvOptions(envFilePaths: new[] { Path.Combine(".","..", ".env") }));
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Projects, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.18.0-beta.2</span></li><li><span>dotenv.net, 4.0.0</span></li></ul></div></div>

# %%
var tenantId = Environment.GetEnvironmentVariable("TENANT_ID");
var projectEndpoint = Environment.GetEnvironmentVariable("AI_FOUNDRY_PROJECT_ENDPOINT");
var modelDeployment = Environment.GetEnvironmentVariable("MODEL_DEPLOYMENT_NAME");
Console.WriteLine($"🔑 Using Tenant ID: {tenantId}");

AIProjectClient projectClient;

try
{
    var credential = new DefaultAzureCredential(new DefaultAzureCredentialOptions
    {
        TenantId = tenantId
    });

    projectClient = new AIProjectClient(new Uri(projectEndpoint), credential);
    Console.WriteLine("✅ Successfully initialized AIProjectClient");
}
catch (Exception ex)
{
    Console.WriteLine($"❌ Error initializing AIProjectClient: {ex.Message}");
    throw;
}
# Out:
# 🔑 Using Tenant ID: a947c9f2-c41c-4792-96cf-24cb4e036161
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# # 2. Creating our Fun & Fit Health Advisor Agent 🏋️
#
# We'll create an Agent specialized in general health and wellness. We'll explicitly mention disclaimers in its instructions, so it never forgets to keep it safe! The instructions also ask the agent to focus on general fitness, dietary tips, and always encourage the user to seek professional advice.

# %%
async Task<AgentVersion> CreateHealthAdvisorAgent()
{
    try
    {
        var modelName = Environment.GetEnvironmentVariable("MODEL_DEPLOYMENT_NAME"); 
        var agentDefinition = new PromptAgentDefinition(modelName)
        {
            Instructions = @"You are a friendly AI Health Advisor.
            You provide general health, fitness, and nutrition information, but always:
            1. Include medical disclaimers.
            2. Encourage the user to consult healthcare professionals.
            3. Provide general, non-diagnostic advice around wellness, diet, and fitness.
            4. Clearly remind them you're not a doctor.
            5. Encourage safe and balanced approaches to exercise and nutrition.
            "
        };
        AgentVersion agentVersion = await projectClient.Agents.CreateAgentVersionAsync(
            agentName:"fun-fit-health-advisor", 
            options: new(agentDefinition));
        Console.WriteLine($"Agent created (id: {agentVersion.Id}, name: {agentVersion.Name}, version: {agentVersion.Version})");
        return agentVersion;
    }
    catch (Exception ex)
    {
        Console.WriteLine($"❌ Error creating Health Advisor Agent: {ex.Message}");
        return null;
    }   
}

var healthAdvisorAgent = await CreateHealthAdvisorAgent();
# Out:
# Agent created (id: fun-fit-health-advisor:2, name: fun-fit-health-advisor, version: 2)

# %% [markdown]
# # 3. Managing Our Health Conversations 💬
#
# A conversation (or thread) is where we'll store the user's messages and the agent's responses about health topics. Let's create a new thread dedicated to Health & Fitness Q&A.

# %%
async Task<ProjectConversation> StartHealthConversation()
{
    ProjectConversation conversation = await projectClient.OpenAI.Conversations.CreateProjectConversationAsync();
    return conversation;
} 
ProjectConversation healthConversation = await StartHealthConversation();
Console.WriteLine($"Started Health Conversation (id: {healthConversation.Id})");
# Out:
# Started Health Conversation (id: conv_f25ceeccbc77a5ca00q7cbexP0sDq4tgnyQN1ZKi7bPoarwMEW)

# %% [markdown]
# # 4. Asking Health & Fitness Questions 🏃‍♂️
#
# We'll create messages from the user about typical health questions. For example, **"How do I calculate my BMI?"** or **"What's a balanced meal for an active lifestyle?"**. We'll let our Health Advisor Agent respond, always remembering that disclaimer!

# %%
#pragma warning disable OPENAI001
ProjectResponsesClient responsesClient = null;
async Task<ResponseResult> ChatWithHealthAgent(string userQuestion)
{
    Console.WriteLine($"👤 User: {userQuestion}");
    try
    {
    if(responsesClient == null)
    {
        responsesClient = projectClient.OpenAI.GetProjectResponsesClientForAgent(
            defaultAgent: healthAdvisorAgent,
            defaultConversationId: healthConversation.Id);
    }

    ResponseResult response = await responsesClient.CreateResponseAsync(userQuestion);
    Console.WriteLine("✅ Agent processing completed!");
    Console.WriteLine("🤖 Agent:");
    Console.WriteLine(response.GetOutputText());
    return response;
    }
    catch (Exception ex)
    {
        Console.WriteLine($"❌ Error during chat with Health Agent: {ex.Message}");
        return null;
    }
}

# %%
#pragma warning disable OPENAI001
Console.WriteLine("🧪 Testing the Health & Fitness Agent...");

Console.WriteLine("Test 1: Simple Health Question ✅");

Console.WriteLine("Test 2: Workout Advice");
ResponseResult response1 = await ChatWithHealthAgent("What's a good 30-minute workout routine for a beginner who wants to build strength?");
Console.WriteLine();

Console.WriteLine("Test 3: Nutrition Advice");
ResponseResult response2 = await ChatWithHealthAgent("Can you suggest a balanced meal plan for someone aiming to increase muscle mass?");
Console.WriteLine();

Console.WriteLine("Test 4: Goal Setting");
ResponseResult response3 = await ChatWithHealthAgent("How can I set realistic fitness goals for someone who wants to lose 20 pounds safely?");

Console.WriteLine();
int successfulTests = new object[] { true, response1, response2, response3 }.Count(r => r != null);
Console.WriteLine($"📊 Summary: {successfulTests}/4 tests passed successfully");
# Out:
# 🧪 Testing the Health & Fitness Agent...
# Test 1: Simple Health Question ✅
# Test 2: Workout Advice
# 👤 User: What's a good 30-minute workout routine for a beginner who wants to build strength?
# ✅ Agent processing completed!
# 🤖 Agent:
# Great question! For a beginner wanting to build strength in a safe and effective way within 30 minutes, here’s a balanced workout routine you can try. Remember, start with light weights or just your body weight to focus on form and avoid injury.
#
# ### 30-Minute Beginner Strength Workout
#
# **Warm-up (5 minutes):**
# - Jumping jacks or marching in place – 2 minutes
# - Arm circles – 1 minute
# - Bodyweight squats – 2 minutes (slow and controlled)
#
# **Workout (20 minutes):**
# Perform 2 sets of each exercise with 45 seconds rest between sets.
#
# 1. **Bodyweight Squats** – 12 reps
#    (Targets legs and glutes)
#
# 2. **Incline Push-ups** (hands on a stable surface like a bench) – 8 to 12 reps
#    (Targets chest, shoulders, and triceps)
#
# 3. **Bent-over Dumbbell Rows** (use light weights or water bottles) – 10 reps per arm
#    (Targets upper back and biceps)
#
# 4. **Glute Bridges** – 15 reps
#    (Targets glutes and lower back)
#
# 5. **Plank** – Hold for 20-30 seconds
#    (Targets core)
#
# 6. **Standing Overhead Dumbbell Press** – 10 reps
#    (Targets shoulders)
#
# **Cool-down (5 minutes):**
# - Gentle stretching focusing on major muscle groups
# - Deep breathing exercises
#
# ---
#
# ### Important Notes:
# - **Form is key:** Prioritize proper technique over the number of reps or weight.
# - **Rest:** If you feel too fatigued, take a longer rest between sets.
# - **Progress gradually:** As you get stronger, increase the reps, sets, or weights slowly.
# - **Listen to your body:** Stop if you experience pain (not to be confused with normal muscle fatigue).
#
# ---
#
# **Disclaimer:** I’m not a doctor. This advice is general and non-diagnostic. It’s always best to consult with a healthcare provider or a certified fitness professional before beginning any new exercise program, especially if you have existing health concerns or conditions.
#
# Would you also like some beginner-friendly nutrition tips to complement your strength training?
#
# Test 3: Nutrition Advice
# 👤 User: Can you suggest a balanced meal plan for someone aiming to increase muscle mass?
# ✅ Agent processing completed!
# 🤖 Agent:
# Absolutely! A balanced meal plan to support muscle growth focuses on providing enough protein to repair and build muscle, healthy carbohydrates for energy, and fats for overall health. Hydration and nutrient timing are also important.
#
# Here’s a simple example of a one-day meal plan for muscle gain. Remember, individual calorie needs vary based on factors like age, weight, activity level, and metabolism.
#
# ---
#
# ### Balanced Muscle-Building Meal Plan (Sample Day)
#
# **Breakfast:**
# - 3 scrambled eggs (or egg whites if preferred)
# - 1 slice whole-grain toast or a small bowl of oatmeal
# - 1 cup mixed berries or a banana
# - 1 cup low-fat milk or a dairy alternative
#
# **Mid-Morning Snack:**
# - Greek yogurt (unsweetened) with a handful of nuts or seeds
# - 1 small apple or pear
#
# **Lunch:**
# - Grilled chicken breast or tofu (about 4-6 oz)
# - 1 cup cooked quinoa or brown rice
# - Steamed mixed vegetables (broccoli, carrots, bell peppers)
# - 1 tablespoon olive oil or avocado for healthy fats
#
# **Afternoon Snack:**
# - Protein smoothie with a scoop of protein powder, a handful of spinach, 1 banana, and almond milk
# - A small handful of almonds or walnuts
#
# **Dinner:**
# - Baked salmon or lean beef (4-6 oz)
# - Sweet potato (medium)
# - Large mixed green salad with olive oil and vinegar dressing
#
# **Optional Evening Snack (if hungry):**
# - Cottage cheese or a few boiled eggs
# - Sliced cucumber or carrots
#
# ---
#
# ### General Guidelines:
# - Aim for **about 1.2 to 2.0 grams of protein per kilogram of body weight** per day, spread over meals.
# - Include carbohydrates especially around your workout times for energy and recovery.
# - Don’t neglect healthy fats (avocados, nuts, olive oil) for hormone balance and overall health.
# - Stay well hydrated—water is essential!
# - Try to eat whole, minimally processed foods as much as possible.
#
# ---
#
# **Disclaimer:** This is general nutrition guidance and not a personalized diet plan. Nutritional needs can vary widely among individuals, so it’s a good idea to discuss your goals and dietary needs with a registered dietitian, nutritionist, or your healthcare provider before making significant changes to your diet.
#
# If you want, I can also give you some tips on how to time your meals around workouts or suggest specific protein sources!
#
# Test 4: Goal Setting
# 👤 User: How can I set realistic fitness goals for someone who wants to lose 20 pounds safely?
# ✅ Agent processing completed!
# 🤖 Agent:
# Setting realistic and safe fitness goals is key to sustainable weight loss and overall health. Losing 20 pounds is definitely achievable with the right approach, but it’s important to focus on gradual progress and healthy habits rather than quick fixes.
#
# ### Tips for Setting Realistic Fitness Goals to Lose 20 Pounds Safely:
#
# 1. **Set a Reasonable Timeline:**
#    - Aim to lose about 1 to 2 pounds per week. This pace is considered safe and sustainable by many health experts.
#    - For 20 pounds, that means roughly 10 to 20 weeks (2.5 to 5 months).
#
# 2. **Break It Down Into Smaller Milestones:**
#    - Instead of focusing only on the final 20-pound goal, set mini-goals like “lose 5 pounds in the next month.”
#    - Celebrate each small win to stay motivated.
#
# 3. **Combine Nutrition and Exercise:**
#    - Weight loss typically comes down to creating a calorie deficit, which can be done by eating healthier and moving more.
#    - Focus on balanced meals with plenty of protein, fiber, and healthy fats to keep you full and energized.
#    - Incorporate a mix of cardio (walking, cycling, swimming) and strength training (to build muscle and boost metabolism).
#
# 4. **Track Your Progress:**
#    - Keep a journal or use an app to monitor your workouts, meals, and how you feel.
#    - Measurements and how clothes fit can also be good indicators, not just the scale.
#
# 5. **Make Behavior and Lifestyle Changes:**
#    - Prioritize adequate sleep (7-9 hours per night).
#    - Manage stress with techniques like meditation or yoga, as high stress can impact weight.
#    - Stay consistent rather than aiming for perfection.
#
# 6. **Be Flexible and Patient:**
#    - Weight loss is often nonlinear; some weeks are easier than others.
#    - Avoid crash diets or extreme exercise, which can cause burnout or injury.
#
# ---
#
# ### Example Goal-Setting Approach:
#
# - **Long-term goal:** Lose 20 pounds safely in 4 months.
# - **Short-term goal:** Lose 1-2 pounds per week by exercising 3-4 times a week and improving diet quality.
# - **Behavior goal:** Add at least 30 minutes of moderate activity most days and cut back on sugary drinks/snacks.
# - **Motivation:** Improve energy levels and feel stronger.
#
# ---
#
# **Disclaimer:** I am not a doctor, and this is general advice. It’s important to consult with a healthcare professional or certified trainer to develop a plan tailored to your personal health, medical history, and lifestyle. Safe and balanced approaches work best for lasting results!
#
# Would you like suggestions for beginner workouts or tips to improve meal planning as part of your weight loss journey?
#
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# # 5. Final Test: Complex Health Question 🧹

# %%
#pragma warning disable OPENAI001
// Displat Conversation History given a conversation ID
async Task ShowConversationHistory(string conversationId)
{
    if(string.IsNullOrEmpty(conversationId))
    {
        Console.WriteLine("❌ No Conversation ID provided.");
        return;
    }
    try
    {

    Console.WriteLine($"📝 Conversation History for ID: {conversationId}");
    var itemCount = 0;
    await foreach (AgentResponseItem item in projectClient.OpenAI.Conversations.GetProjectConversationItemsAsync(
    healthConversation.Id, order:"asc"))
    {
        itemCount++;
        var messageResponseItem = item.AsResponseResultItem() as MessageResponseItem;
        var role = messageResponseItem.Role.ToString();
        var roleEmoji = role == "User" ? "👤" : "🤖";
        Console.WriteLine($"{itemCount}. {roleEmoji} {role}:");
        Console.WriteLine(new string('-', 40));
        var content = messageResponseItem.Content?[0]?.Text;
        if(content != null && content.Length > 0)
        {
            if(content.Length > 500)
            {
                Console.WriteLine($"{content.Substring(0,500)}... [truncated]");
            } 
            else
            {
                Console.WriteLine(content);
            }
        }
        else
        {
            Console.WriteLine("No content available.");
        }
    }
    Console.WriteLine($"\n📊 Total messages in conversation: {itemCount}");
    }
    catch(Exception ex)
    {
        Console.WriteLine($"❌ Error retrieving conversation history: {ex.Message}");
    }
}

await ShowConversationHistory(healthConversation.Id);
Console.WriteLine(new string('=', 40));
# Out:
# 📝 Conversation History for ID: conv_f25ceeccbc77a5ca00q7cbexP0sDq4tgnyQN1ZKi7bPoarwMEW
# 1. 👤 User:
# ----------------------------------------
# What's a good 30-minute workout routine for a beginner who wants to build strength?
# 2. 🤖 Assistant:
# ----------------------------------------
# Great question! For a beginner wanting to build strength in a safe and effective way within 30 minutes, here’s a balanced workout routine you can try. Remember, start with light weights or just your body weight to focus on form and avoid injury.
#
# ### 30-Minute Beginner Strength Workout
#
# **Warm-up (5 minutes):**
# - Jumping jacks or marching in place – 2 minutes
# - Arm circles – 1 minute
# - Bodyweight squats – 2 minutes (slow and controlled)
#
# **Workout (20 minutes):**
# Perform 2 sets of each e... [truncated]
# 3. 👤 User:
# ----------------------------------------
# Can you suggest a balanced meal plan for someone aiming to increase muscle mass?
# 4. 🤖 Assistant:
# ----------------------------------------
# Absolutely! A balanced meal plan to support muscle growth focuses on providing enough protein to repair and build muscle, healthy carbohydrates for energy, and fats for overall health. Hydration and nutrient timing are also important.
#
# Here’s a simple example of a one-day meal plan for muscle gain. Remember, individual calorie needs vary based on factors like age, weight, activity level, and metabolism.
#
# ---
#
# ### Balanced Muscle-Building Meal Plan (Sample Day)
#
# **Breakfast:**
# - 3 scrambled egg... [truncated]
# 5. 👤 User:
# ----------------------------------------
# How can I set realistic fitness goals for someone who wants to lose 20 pounds safely?
# 6. 🤖 Assistant:
# ----------------------------------------
# Setting realistic and safe fitness goals is key to sustainable weight loss and overall health. Losing 20 pounds is definitely achievable with the right approach, but it’s important to focus on gradual progress and healthy habits rather than quick fixes.
#
# ### Tips for Setting Realistic Fitness Goals to Lose 20 Pounds Safely:
#
# 1. **Set a Reasonable Timeline:**
#    - Aim to lose about 1 to 2 pounds per week. This pace is considered safe and sustainable by many health experts.
#    - For 20 pounds,... [truncated]
# 7. 👤 User:
# ----------------------------------------
# I'm a 35-year-old office worker who sits most of the day. I want to start exercising but I have limited time (only 20 minutes, 3 times per week). What would you recommend for someone with back pain from sitting too long?
# 8. 🤖 Assistant:
# ----------------------------------------
# Thanks for sharing your situation! Sitting for long periods can contribute to back discomfort, so incorporating gentle, targeted exercises that strengthen your core and improve posture is a great idea, especially when you’re short on time.
#
# Here’s a **safe, beginner-friendly 20-minute workout routine** you can do 3 times a week, designed to help reduce back pain related to prolonged sitting while fitting your schedule:
#
# ---
#
# ### 20-Minute Beginner-Friendly Workout for Back Health & Strength
#
# **W... [truncated]
#
# 📊 Total messages in conversation: 8
# ========================================

# %%
Console.WriteLine("🔍 Final Test: Complex Health Question");
Console.WriteLine(new string('=', 40));

var finalResponse = await ChatWithHealthAgent("I'm a 35-year-old office worker who sits most of the day. I want to start exercising but I have limited time (only 20 minutes, 3 times per week). What would you recommend for someone with back pain from sitting too long?");

if (finalResponse != null)
{
    Console.WriteLine("\n✅ Final test successful!");
    Console.WriteLine("\n🎯 Our Health & Fitness Agent is fully functional and ready to help users with personalized advice!");
}
else
{
    Console.WriteLine("\n❌ Final test failed.");
}
# Out:
# 🔍 Final Test: Complex Health Question
# ========================================
# 👤 User: I'm a 35-year-old office worker who sits most of the day. I want to start exercising but I have limited time (only 20 minutes, 3 times per week). What would you recommend for someone with back pain from sitting too long?
# ✅ Agent processing completed!
# 🤖 Agent:
# Thanks for reaching out! Sitting for extended periods can definitely contribute to back pain, so starting an exercise routine focused on strengthening your core, improving posture, and increasing mobility is a smart move—especially when your time is limited.
#
# Here’s a **simple and effective 20-minute workout you can do 3 times a week** to help ease back pain and build strength:
#
# ---
#
# ### 20-Minute Back-Friendly Workout for Office Workers
#
# **Warm-up (3 minutes):**
# - Gentle marching in place or walking (2 minutes)
# - Shoulder rolls and neck stretches (1 minute)
#
# **Main Circuit (14 minutes):**
# Do the following exercises in a circuit, performing each for about 40 seconds, followed by 20 seconds rest. Repeat the circuit twice.
#
# 1. **Bird-Dog:**
#    - On hands and knees, extend your right arm and left leg, hold briefly, then switch sides.
#    - Builds core stability and strengthens lower back.
#
# 2. **Glute Bridge:**
#    - Lying on your back with knees bent, lift hips toward the ceiling while squeezing glutes.
#    - Strengthens glutes and supports the lower back.
#
# 3. **Wall Angels:**
#    - Stand with your back against a wall; slowly slide your arms up and down, keeping contact with the wall.
#    - Improves shoulder and upper back posture.
#
# 4. **Modified Plank (on knees):**
#    - Hold a plank position on your forearms and knees, keeping your core engaged.
#    - Builds core strength to support your spine.
#
# 5. **Seated Spinal Twist:**
#    - Sit tall on a chair; gently twist your upper body to one side, hold, then switch.
#    - Increases spinal mobility and relieves tension.
#
# **Cool-down (3 minutes):**
# - Child’s Pose stretch on knees (1 minute)
# - Deep breathing and gentle neck stretches (2 minutes)
#
# ---
#
# ### Additional Tips:
# - Try to stand up and move briefly every 30-60 minutes during work.
# - Pay attention to your sitting posture—feet flat, back supported, and shoulders relaxed.
# - If possible, consider ergonomic adjustments to your workspace (chair, desk height).
#
# ---
#
# **Note:** Because you have back pain, it’s important to listen to your body. If you feel any sharp pain or discomfort during exercises, stop and consult a healthcare professional or physical therapist to tailor your routine safely.
#
# ---
#
# **Disclaimer:** I’m not a doctor. This advice is general and non-diagnostic. For personalized care, especially related to back pain, please consult a healthcare provider before starting a new fitness program.
#
# If you'd like, I can also help you with simple stretching routines or tips to improve your workstation setup! Would you be interested?
#
# ✅ Final test successful!
#
# 🎯 Our Health & Fitness Agent is fully functional and ready to help users with personalized advice!

# %% [markdown]
# # 5. Cleanup 🧹
#
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
// Clean up resources
// await projectClient.OpenAI.Conversations.DeleteConversationAsync(healthConversation.Id);
// await projectClient.Agents.DeleteAgentAsync(healthAdvisorAgent.Id);
Console.WriteLine("🗑️ Deleted agent");
Console.WriteLine("✅ Cleanup completed!");

# %% [markdown]
# # Congratulations! 🏆
#
# You've successfully built a **Fun & Fit Health Advisor** that can:
#
# 1. **Respond** to basic health and fitness questions.
# 2. **Use disclaimers** to encourage safe, professional consultation.
# 3. **Provide** general diet and wellness information.
# 4. **Use** the synergy of **Azure AI Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to provide more specialized info.
# - Evaluate your AI's performance with **Azure AI Evaluation**!
# - Add **OpenTelemetry** or **Azure Monitor** for deeper insights.
# - Incorporate **function calling** if you want to handle things like advanced calculation or direct data analysis.
#
# **Let's proceed to [2-code_interpreter.ipynb](./2-code_interpreter.ipynb)**
#
# Happy (healthy) coding! 💪

# %% [markdown]
# # 🎯 Summary & Next Steps
#
# Congratulations! You've successfully:
#
# ✅ Connected to Azure AI Foundry - Established secure connection using authentication <br>
# ✅ Created an AI Agent - Built a specialized Health & Fitness Assistant <br>
# ✅ Implemented Chat Functionality - Created functions to interact with the agent <br>
# ✅ Tested Multiple Scenarios - Verified the agent works for various health questions <br>
#
# ### Key Concepts Learned
# - **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# - **Conversations** - Conversation sessions that maintain context between messages
# - **Responses** - Individual communications between users and agents
#
# ### What's Next?
#
# This was just the beginning! In the next notebooks, you'll learn about:
#
# - Code Interpreter - Agents that can write and execute code
# - File Search - Agents that can search through documents
# - Bing Grounding - Agents with real-time web search capabilities
# - AI Search Integration - Agents connected to your knowledge bases
# - Azure Functions - Agents that can trigger actions and workflows
#
# ### 🔧 Key Takeaways
# - The **CreateResponse** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within Conversation objects
# - The agent provides responsible AI disclaimers for health advice
# - Error handling is crucial when working with AI services
#
# Ready to explore more advanced agent capabilities? Continue with the next notebook! 🚀
